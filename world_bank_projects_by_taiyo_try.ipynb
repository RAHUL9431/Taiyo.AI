# %% [markdown]
# ### import library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Datasets

# %%
df=pd.read_csv(r'C:\Users\RAHUL\Desktop\New project\Taiyo.ai task-20230305T142417Z-001\Taiyo.ai task\world_bank_projects.csv')

# %%
df.head()
# Out:
#   Project Id                       Region                          Country  \
# 0    P161086                   South Asia  People's Republic of Bangladesh
# 1    P173281  Latin America and Caribbean                Republic of Haiti
# 2    P173746        East Asia and Pacific       People's Republic of China
# 3    P163836  Eastern and Southern Africa               Republic of Uganda
# 4    P158079        East Asia and Pacific       People's Republic of China
#
#   Project Status                                       Project Name  \
# 0         Active  Bangladesh: Enhancing Digital Government & Eco...
# 1         Active  AF Haiti Rural Accessibility & Resilience Project
# 2         Active  Emerging Infectious Diseases Prevention, Prepa...
# 3         Active   Irrigation for Climate Resilience Project (ICRP)
# 4         Active        China: Jiangxi Eco-industrial Parks Project
#
#                        Project Development Objective  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1001 entries, 0 to 1000
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Project Id                         500 non-null    object
#  1   Region                             1001 non-null   object
#  2   Country                            1001 non-null   object
#  3   Project Status                     1001 non-null   object
#  4   Project Name                       1001 non-null   object
#  5   Project Development Objective      1001 non-null   object
#  6   Implementing Agency                955 non-null    object
#  7   Consultant Services Required       1001 non-null   object
#  8   Project URL                        1001 non-null   object
#  9   Board Approval Date                1001 non-null   object
#  10  Project Closing Date               787 non-null    object
# ...

# %%
df.isna().mean()*100
# Out:
# Project Id                           50.049950
# Region                                0.000000
# Country                               0.000000
# Project Status                        0.000000
# Project Name                          0.000000
# Project Development Objective         0.000000
# Implementing Agency                   4.595405
# Consultant Services Required          0.000000
# Project URL                           0.000000
# Board Approval Date                   0.000000
# Project Closing Date                 21.378621
# Last Stage Reached                   99.900100
# Financing Type                        0.000000
# Total Project Cost $US                0.000000
# IBRD Commitment $US                  99.900100
# IDA Commitment $US                   99.900100
# Total IDA and IBRD Commitment $US     0.000000
# Grant Amount $US                     70.129870
# Borrower                              4.195804
# Lending Instrument                    0.000000
# ...

# %%
df.shape
# Out:
# (1001, 28)

# %%
# drop column 
df = df.drop(['Last Stage Reached','IBRD Commitment $US','IDA Commitment $US','Theme 1','Theme 2','Environmental Assessment Category','Environmental and Social Risk'], axis=1)

# %%
df.head()
# Out:
#   Project Id                       Region                          Country  \
# 0    P161086                   South Asia  People's Republic of Bangladesh
# 1    P173281  Latin America and Caribbean                Republic of Haiti
# 2    P173746        East Asia and Pacific       People's Republic of China
# 3    P163836  Eastern and Southern Africa               Republic of Uganda
# 4    P158079        East Asia and Pacific       People's Republic of China
#
#   Project Status                                       Project Name  \
# 0         Active  Bangladesh: Enhancing Digital Government & Eco...
# 1         Active  AF Haiti Rural Accessibility & Resilience Project
# 2         Active  Emerging Infectious Diseases Prevention, Prepa...
# 3         Active   Irrigation for Climate Resilience Project (ICRP)
# 4         Active        China: Jiangxi Eco-industrial Parks Project
#
#                        Project Development Objective  \
# ...

# %%
df['Consultant Services Required'].unique()
# Out:
# array(['No', 'Yes', 'TBD', 'Consultant Services Required'], dtype=object)

# %%
df['Financing Type'].unique()
# Out:
# array(['Other', 'IDA', 'IBRD', 'Grants', 'Financing Type'], dtype=object)

# %%
df['Grant Amount $US'].shape
# Out:
# (1001,)

# %%
## Fillna 
df['Grant Amount $US']=df.fillna(df['Grant Amount $US']).mean()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp/ipykernel_10012/4061909132.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df['Grant Amount $US']=df.fillna(df['Grant Amount $US']).mean()

# %%
df['Grant Amount $US'].isna().sum()
# Out:
# 1001

# %%
# Replace NaN values with 'Not available'
df.fillna('Not available', inplace=True)

# %%
df.sample(5)
# Out:
#         Project Id                        Region  \
# 621  Not available    Western and Central Africa
# 514  Not available  Middle East and North Africa
# 776  Not available                    South Asia
# 673  Not available   Eastern and Southern Africa
# 798  Not available   Latin America and Caribbean
#
#                              Country Project Status  \
# 621      Federal Republic of Nigeria         Active
# 514               West Bank and Gaza         Active
# 776  People's Republic of Bangladesh         Active
# 673               Republic of Rwanda         Active
# 798                     Sint Maarten         Active
#
#                                           Project Name  \
# 621         Ogun State Economic Transformation Project
# 514       Wastewater Management Sustainability Project
# 776     Bangladesh Scaling-up Renewable Energy Project
# 673  Rwanda Quality Basic Education for Human Capit...
# 798   Sint Maarten Emergency Debris Management Project
#
# ...

# %%
# Import necessary libraries
import pandas as pd
import spacy

# Load the pre-trained NER model
nlp = spacy.load('en_core_web_sm')

# Load the data
data = df

# Define the function for extracting named entities from text
def extract_entities(text):
    doc = nlp(text)
    entities = []
    for ent in doc.ents:
        entities.append((ent.text, ent.label_))
    return entities

# Apply the function to each column of text data
for column in data.columns:
    data[column+'_entities'] = data[column].apply(extract_entities)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10012/778841313.py in <module>
#       4
#       5 # Load the pre-trained NER model
# ----> 6 nlp = spacy.load('en_core_web_sm')
#       7
#       8 # Load the data
#
# ~\anaconda3\lib\site-packages\spacy\__init__.py in load(name, vocab, disable, enable, exclude, config)
#      52     RETURNS (Language): The loaded nlp object.
#      53     """
# ---> 54     return util.load_model(
#      55         name,
#      56         vocab=vocab,
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model(name, vocab, disable, enable, exclude, config)
#     437     if name in OLD_MODEL_SHORTCUTS:
#     438         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 439     raise IOError(Errors.E050.format(name=name))
#     440
#     441
#
# ...
